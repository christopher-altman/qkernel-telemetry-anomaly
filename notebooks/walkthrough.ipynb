# %% [markdown]
# # Quantum Kernel Telemetry Anomaly Detection
#
# This notebook runs the end-to-end pipeline on the synthetic telemetry generator.

# %%
# !python -m src.main --n-train 300 --n-test 150 --anomaly-rate 0.15 --outdir results/notebook_run

# %%
from pathlib import Path
import json
print(json.loads(Path('results/notebook_run/metrics.json').read_text()))

# %%
from PIL import Image
Image.open('figures/roc.png')

# %%
Image.open('figures/kernel_pca.png')
